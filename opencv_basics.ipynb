# %%
from matplotlib import pyplot as plt

# %%
import cv2

# %% [markdown]
# #plotting an image

# %%
img1=cv2.imread("images.jfif",0)

# %%
plt.imshow(img1)

# %%
img2=cv2.imread("images.jfif",0)

# %%
plt.imshow(img2)

# %%
result1=img1+img2

# %%
plt.imshow(result1)

# %%
img3=cv2.imread("img3.jfif")

# %%
plt.imshow(img3)

# %%
img4=cv2.imread("img3.jfif")

# %%
plt.imshow(img4)

# %%
result2=img3-img4

# %%
plt.imshow(result2)

# %%
result3=(img3*img3)

# %%
plt.imshow(result3)

# %%
result4=(img2/img2)

# %%
plt.imshow(result4)

# %%
img1=cv2.imread("Camera Roll/img4.jpg")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("Original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("Blurred")
plt.xticks([]),plt.yticks([])
plt.show()

# %%
img1=cv2.imread("images.jfif")

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img1,(int(width*2),int(height)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %%
import numpy as np

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img,m,(height,width))
plt.imshow(dst)
